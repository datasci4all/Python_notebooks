# %%
#### Interpret a Histogram ####

# Importing necessary libraries
import pandas as pd
from plotnine import ggplot, aes, geom_histogram, xlab, ggtitle

# Import the data
countries = pd.read_csv("countries.csv")

# Plot the data
(ggplot(countries, aes(x = "life_expectancy")) +
  geom_histogram(bins = 20, fill = "blue", color = "black") +
  xlab("Life Expectancy") +
  ggtitle("Life Expectancy Worldwide")
)
# Out:
# /usr/local/lib/python3.10/dist-packages/plotnine/layer.py:284: PlotnineWarning: stat_bin : Removed 6 rows containing non-finite values.
# <Figure Size: (640 x 480)>
