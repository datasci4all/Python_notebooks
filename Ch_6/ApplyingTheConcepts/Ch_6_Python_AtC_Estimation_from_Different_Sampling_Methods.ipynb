# %%
#### Estimation from Different Sampling Methods ####

# Importing necessary libraries
import pandas as pd

## SRS Stats
print("SRS Statistics:")
srs = pd.read_csv("student_gpa_srs.csv")

print(srs.groupby("class").agg(['mean', 'count']))

print("Overall Average:")
print(srs['gpa'].mean())

## Proportional Stratified Stats
print("Stratified Random Sample Statistics:")
strat_samp = pd.read_csv("student_gpa_strat.csv")

print(strat_samp.groupby("class").agg(['mean', 'count']))

print("Overall Average:")
print(strat_samp['gpa'].mean())


## Balanced Stratified Stats
print("Balanced Stratified Random Sample Statistics:")
bal_strat_samp = pd.read_csv("student_gpa_bal_strat.csv")

print(bal_strat_samp.groupby("class").agg(['mean', 'count']))

print("Overall Average:")
print(bal_strat_samp['gpa'].mean())
# Out:
# SRS Statistics:
#                   gpa
#                  mean count
# class
# first-year   3.764722    27
# fourth-year  2.960798    24
# second-year  3.531015    25
# third-year   3.098885    24
# Overall Average:
# 3.35355245436231
# Stratified Random Sample Statistics:
#                   gpa
#                  mean count
# class
# first-year   3.746739    30
# fourth-year  2.964777    20
# second-year  3.485053    30
# third-year   3.125718    20
# Overall Average:
# 3.387636528738268
# Balanced Stratified Random Sample Statistics:
#                   gpa
#                  mean count
# class
# first-year   3.756948    25
# fourth-year  3.072917    25
# second-year  3.412779    25
# third-year   3.063874    25
# Overall Average:
# 3.3266293927984747
